# %%
import torch
import torch.nn.functional as F
from torchvision import transforms
from PIL import Image
import matplotlib.pyplot as plt
from siamese_signature import SiameseNetwork
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 6
#       4 from PIL import Image
#       5 import matplotlib.pyplot as plt
# ----> 6 from siamese_signature import SiameseNetwork
#
# ModuleNotFoundError: No module named 'siamese_signature'

# %%
# %run /home/marco/Projet_du_Fin_DEtude_M2/siamese_signature.ipynb
